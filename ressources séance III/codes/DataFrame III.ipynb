# %%
#########################################################
# DataFrames part III 
# Author : Rodrique KAFANDO
# Destination : Master FD&IA - UV-BF
# Online : 27.07.2021
#########################################################

# %% [markdown]
# # This chapter is focused on data extraction
# * filter, select, reindex, etc.
# * comment selectionner plusieurs colonnes
# * comment indexer plusieurs cellules
# * comment modifier le contenu d'une cellule
# * etc.

# %%
import pandas as pd

# %%
df = pd.read_csv('./pandas/jamesbond.csv')
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # The .set_index() and the .reset_index() Methods

# %%
# The set_index() permet de specifier une colonne existante comme index du DataFrame
# 1) elle peut se faire directrment lors de la lecture du fichier CSV
df = pd.read_csv('./pandas/jamesbond.csv', index_col = 'Film')
df
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# 2) mais lorsque nous avons déjà les données sous forme de df, nous devons utiliser .set_index()
df = pd.read_csv('./pandas/jamesbond.csv')
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# specifier inplace = True pour rendre la nouvelle valeur permanente
df.set_index('Film')
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df.set_index(keys = 'Film', inplace = True)
df.head(3)
# Maintenant, comment fair epour utiliser 'Year' comme index, au lieu de 'Film'?
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
# comment revenir à la specification de l'index initiale? en utilisant reset_index()
df.reset_index().head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # Retrieve rows by index Label with *.loc[]* accessor

# %%
# nous revenons sur les mêmes données, et nous utilisaons 'Film' comme colonne index
df = pd.read_csv('./pandas/jamesbond.csv')

# %%
df.set_index(keys = 'Film', inplace = True)

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# par exemple, si nous voulons les informations sur le film dont le nom est 'Casino Royale' or Goldfinger
df.loc[['Casino Royale', 'Goldfinger']]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Goldfinger     1964  Sean Connery     Guy Hamilton       820.4    18.6
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3
# Goldfinger                   3.2

# %%
df.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
# comme les listes, nous pouvons aussi definir une plage
df.loc['Dr. No':'Thunderball']
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %% [markdown]
# # Retrieve rows by index Position with *.iloc[]* accessor

# %%
# la syntax est similaire à celle de .loc[]
df.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
df.reset_index(inplace=True )

# %%
df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
# acceder la ligne à la position 5
df.iloc[5]
# Out:
# Film                 You Only Live Twice
# Year                                1967
# Actor                       Sean Connery
# Director                   Lewis Gilbert
# Box Office                         514.2
# Budget                              59.9
# Bond Actor Salary                    4.4
# Name: 5, dtype: object

# %%
df.iloc[0:10:2]
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 2       820.4    18.6                3.2
# 4       315.0    85.0                NaN
# 6       291.5    37.3                0.6
# 8       460.3    30.8                NaN

# %%
df.iloc[[2,5,10,8]]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 5    You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
# 8       Live and Let Die  1973   Roger Moore   Guy Hamilton       460.3
#
#     Budget  Bond Actor Salary
# 2     18.6                3.2
# 5     59.9                4.4
# 10    45.1                NaN
# 8     30.8                NaN

# %%
# Remarques, .iloc[] est utilisable dans le cas où l'on peut utiliser .loc[]

# %% [markdown]
# ### Utiliser des seconds arguments avecles accesseurs .loc et .iloc pour plus de flexibilité

# %%
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# set 'Film' as index column
df.set_index('Film', inplace  = True)

# %%
# nous pouvons specifier 1) le label de l'index, et la valeur de la colonne correspondante
# ex : qui est le directeur du film dont le titre est 'Thunderball'?
# df.loc['lable', 'nom colonne' ou [noms colonnes]]
df.loc['Thunderball', ['Actor','Budget']]
#df.loc[['Goldfinger','Thunderball'], ['Actor','Budget']]
# Out:
# Actor     Sean Connery
# Budget            41.9
# Name: Thunderball, dtype: object

# %%
# autrement nous pouvons utiliser un intervalle de valeurs
df.loc[['Goldfinger'], 'Actor':'Budget']
# Out:
#                    Actor      Director  Box Office  Budget
# Film
# Goldfinger  Sean Connery  Guy Hamilton       820.4    18.6

# %%
#
df.loc['Goldfinger':'The Spy Who Loved Me', 'Actor':'Budget']
# Out:
#                                           Actor       Director  Box Office  \
# Film
# Goldfinger                         Sean Connery   Guy Hamilton       820.4
# Thunderball                        Sean Connery  Terence Young       848.1
# Casino Royale                       David Niven     Ken Hughes       315.0
# You Only Live Twice                Sean Connery  Lewis Gilbert       514.2
# On Her Majesty's Secret Service  George Lazenby  Peter R. Hunt       291.5
# Diamonds Are Forever               Sean Connery   Guy Hamilton       442.5
# Live and Let Die                    Roger Moore   Guy Hamilton       460.3
# The Man with the Golden Gun         Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me                Roger Moore  Lewis Gilbert       533.0
#
#                                  Budget
# Film
# Goldfinger                         18.6
# Thunderball                        41.9
# Casino Royale                      85.0
# You Only Live Twice                59.9
# ...

# %%
#.ILOC, je vous laisse vous exercer avec .iloc[]
df.iloc[3]
# Out:
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: Thunderball, dtype: object

# %% [markdown]
# # set the value for a specific cell

# %%
# acteur du filmn dont le nom est ?
df.loc['Thunderball', 'Actor']
# Out:
# 'Sean Connery'

# %%
df.loc['Thunderball', 'Actor'] = 'Mr. Sean Connery'

# %%
df.loc['Thunderball', 'Actor']
# Out:
# 'Mr. Sean Connery'

# %%
# now if i want to modify a multiple values
df.loc['Thunderball', ['Actor', 'Box Office', 'Budget']]
# Out:
# Actor         Mr. Sean Connery
# Box Office               848.1
# Budget                    41.9
# Name: Thunderball, dtype: object

# %%
# modifions ces valeurs
df.loc['Thunderball', ['Actor', 'Box Office', 'Budget']] = ['Sean Connery',700, 50]

# %%
df.loc['Thunderball', ['Actor', 'Box Office', 'Budget']]
# Out:
# Actor         Sean Connery
# Box Office             700
# Budget                  50
# Name: Thunderball, dtype: object

# %% [markdown]
# # Set multiple values in a DF

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       700.0    50.0
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# here's the wrong way to overwrite multiple values
val = df["Actor"] == 'Sean Connery'
df[val]["Actor"]
# Out:
# Film
# Dr. No                   Sean Connery
# From Russia with Love    Sean Connery
# Goldfinger               Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Diamonds Are Forever     Sean Connery
# Never Say Never Again    Sean Connery
# Name: Actor, dtype: object

# %%
# en affectant de cette maniere, c'est comme si nous creons une copie du DF, 
# cela voudrait dire que le DF d'origine ne changera pas, verifions cela plus bas
# le message d'error nous indique les bonnes manières
df[val]["Actor"] = 'Mr. Sean Connery'
# Out:
# /home/rodrique/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       700.0    50.0
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# la solution idéale serait:
val = df["Actor"] == 'Sean Connery'
# .loc utilise directement la reference, et non une copie
df.loc[val, 'Actor'] = 'Mr Sean Connery'

# %%
df.head()
# Out:
#                        Year            Actor       Director  Box Office  \
# Film
# Dr. No                 1962  Mr Sean Connery  Terence Young       448.8
# From Russia with Love  1963  Mr Sean Connery  Terence Young       543.8
# Goldfinger             1964  Mr Sean Connery   Guy Hamilton       820.4
# Thunderball            1965  Mr Sean Connery  Terence Young       700.0
# Casino Royale          1967      David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Thunderball              50.0                4.7
# Casino Royale            85.0                NaN

# %% [markdown]
# # Rename Index Labels or Columns in DataFrame

# %% [markdown]
# ### Rename() methode

# %%
# use mapper() with axis => dictionnary
df.rename(mapper = {'Goldfinger':'Gold  finger', 
                    'Casino Royale':'CasinoRoyale' })
# Out:
#                                  Year            Actor            Director  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %%
# use mapper() with axis => dictionnary
df.rename(mapper = {'Goldfinger':'Gold  finger', 
                    'Casino Royale':'CasinoRoyale'}, axis =0)
# Out:
#                                  Year            Actor            Director  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %%
# use mapper() with axis => dictionnary
df.rename(mapper = {'Goldfinger':'Gold  finger', 
                    'Casino Royale':'CasinoRoyale' }, axis = 'index', inplace = True)

# %%
# use mapper() with axis => dictionnary
df.rename(mapper = {'Goldfinger':'Gold  finger', 
                    'Casino Royale':'CasinoRoyale'}, axis = 'rows' )

# %%
# Use index => same style as mapper, but don't take axis parameter
df.rename(index = {'Goldfinger':'Gold  finger', 
                    'Casino Royale':'CasinoRoyale'}, inplace = True )

# %%
df.head()
# Out:
#                        Year            Actor       Director  Box Office  \
# Film
# Dr. No                 1962  Mr Sean Connery  Terence Young       448.8
# From Russia with Love  1963  Mr Sean Connery  Terence Young       543.8
# Gold  finger           1964  Mr Sean Connery   Guy Hamilton       820.4
# Thunderball            1965  Mr Sean Connery  Terence Young       700.0
# CasinoRoyale           1967      David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Gold  finger             18.6                3.2
# Thunderball              50.0                4.7
# CasinoRoyale             85.0                NaN

# %% [markdown]
# #### Rename columns name

# %%
# rename with mapper(), Why nothong happens ? Because we need to specify the axis level
df.rename(mapper = {'Actor':'Author', 'Director':'supervisor', 'Box Office':'Address' } )
# Out:
#                                  Year            Actor            Director  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %%
# so we have
df.rename(mapper = {'Actor':'Author', 'Director':'supervisor', 'Box Office':'Address' }, axis = 1)
# Out:
#                                  Year           Author          supervisor  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %%
df.rename(mapper = {'Actor':'Author', 'Director':'supervisor', 'Box Office':'Address' }, axis = 'columns')
# Out:
#                                  Year           Author          supervisor  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %%
# or finally use the columns parameter instead the mapper
df.rename(columns = {'Actor':'Author', 'Director':'supervisor', 'Box Office':'Address' })
# Out:
#                                  Year           Author          supervisor  \
# Film
# Dr. No                           1962  Mr Sean Connery       Terence Young
# From Russia with Love            1963  Mr Sean Connery       Terence Young
# Gold  finger                     1964  Mr Sean Connery        Guy Hamilton
# Thunderball                      1965  Mr Sean Connery       Terence Young
# CasinoRoyale                     1967      David Niven          Ken Hughes
# You Only Live Twice              1967  Mr Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969   George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971  Mr Sean Connery        Guy Hamilton
# Live and Let Die                 1973      Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974      Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977      Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ##### rename by using the columns attrbute

# %%
# be careful, the list provided must have the same len() as the number of columns
df.columns = ['Year of','Author Name','Director','Box Office','Budget TTC','Bond Actor Salary']

# %%
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # Delete Rows or columns from DF

# %%
# drop() Method, can call ddirectely on DF => rows or index, or axis  = 0
# need to specify the index value that we want to delete, ex : 'From Russia with Love', or more than one
df.drop('From Russia with Love')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-97ac04f4f790> in <module>
#       1 # drop() Method, can call ddirectely on DF => rows or index, or axis  = 0
#       2 # need to specify the index value that we want to delete, ex : 'From Russia with Love', or more than one
# ----> 3 df.drop('From Russia with Love')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# ...

# %%
df.drop(['Author Name', 'Director'], axis = 1) # or axis = 'columns'
# Out:
#                                  Year of  Box Office  Budget TTC  \
# Film
# Dr. No                              1962       448.8         7.0
# From Russia with Love               1963       543.8        12.6
# Gold  finger                        1964       820.4        18.6
# Thunderball                         1965       700.0        50.0
# CasinoRoyale                        1967       315.0        85.0
# You Only Live Twice                 1967       514.2        59.9
# On Her Majesty's Secret Service     1969       291.5        37.3
# Diamonds Are Forever                1971       442.5        34.7
# Live and Let Die                    1973       460.3        30.8
# The Man with the Golden Gun         1974       334.0        27.7
# The Spy Who Loved Me                1977       533.0        45.1
# Moonraker                           1979       535.0        91.5
# For Your Eyes Only                  1981       449.4        60.2
# ...

# %%
# pop() method, which is permanent method, and returns the poped series. It's takes a single series
actor = df.pop('Author Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Author Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-79cf67175810> in <module>
# ...

# %%
# we also have the del keyword, ex :
del df['Actor']

# %% [markdown]
# # Create random sample with sample Method

# %%
df = pd.read_csv('./pandas/jamesbond.csv', index_col = 'Film')
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# the sample() method
df.sampldf.sample()e() # return a given sample
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN

# %%
df.sample(n = 4) # sepecify N, the number of rows to be extracted randomly
# Out:
#                        Year           Actor        Director  Box Office  \
# Film
# You Only Live Twice    1967    Sean Connery   Lewis Gilbert       514.2
# Die Another Day        2002  Pierce Brosnan    Lee Tamahori       465.4
# Thunderball            1965    Sean Connery   Terence Young       848.1
# Never Say Never Again  1983    Sean Connery  Irvin Kershner       380.0
#
#                        Budget  Bond Actor Salary
# Film
# You Only Live Twice      59.9                4.4
# Die Another Day         154.2               17.9
# Thunderball              41.9                4.7
# Never Say Never Again    86.0                NaN

# %%
df.sample(frac = .50) # will return 25% of the rows, randomly
# Out:
#                                  Year           Actor         Director  \
# Film
# Octopussy                        1983     Roger Moore        John Glen
# A View to a Kill                 1985     Roger Moore        John Glen
# For Your Eyes Only               1981     Roger Moore        John Glen
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Thunderball                      1965    Sean Connery    Terence Young
# The Spy Who Loved Me             1977     Roger Moore    Lewis Gilbert
# From Russia with Love            1963    Sean Connery    Terence Young
# Moonraker                        1979     Roger Moore    Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan    Michael Apted
# Skyfall                          2012    Daniel Craig       Sam Mendes
# ...

# %%
# specify axis value to select columns randomly
df.sample(frac = .50, axis  = 1)
# Out:
#                                  Budget            Director  Bond Actor Salary
# Film
# Dr. No                              7.0       Terence Young                0.6
# From Russia with Love              12.6       Terence Young                1.6
# Goldfinger                         18.6        Guy Hamilton                3.2
# Thunderball                        41.9       Terence Young                4.7
# Casino Royale                      85.0          Ken Hughes                NaN
# You Only Live Twice                59.9       Lewis Gilbert                4.4
# On Her Majesty's Secret Service    37.3       Peter R. Hunt                0.6
# Diamonds Are Forever               34.7        Guy Hamilton                5.8
# Live and Let Die                   30.8        Guy Hamilton                NaN
# The Man with the Golden Gun        27.7        Guy Hamilton                NaN
# The Spy Who Loved Me               45.1       Lewis Gilbert                NaN
# ...

# %% [markdown]
# # The .nsmallest() and .nlargest() columns or rows in a DF

# %%
# elle ppeut etre souvent bien efficcient par rapport à la method sort_values()
# ex:
df.sort_values('Box Office', ascending = False).head()
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Skyfall        2012  Daniel Craig       Sam Mendes       943.5   170.2
# Thunderball    1965  Sean Connery    Terence Young       848.1    41.9
# Goldfinger     1964  Sean Connery     Guy Hamilton       820.4    18.6
# Spectre        2015  Daniel Craig       Sam Mendes       726.7   206.3
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Skyfall                     14.5
# Thunderball                  4.7
# Goldfinger                   3.2
# Spectre                      NaN
# Casino Royale                3.3

# %%
#  .nlargest() nous permet d'extraire les top N plus grandes valeurs
df.nlargest(n = 5, columns = ['Box Office','Budget'])
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Skyfall        2012  Daniel Craig       Sam Mendes       943.5   170.2
# Thunderball    1965  Sean Connery    Terence Young       848.1    41.9
# Goldfinger     1964  Sean Connery     Guy Hamilton       820.4    18.6
# Spectre        2015  Daniel Craig       Sam Mendes       726.7   206.3
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Skyfall                     14.5
# Thunderball                  4.7
# Goldfinger                   3.2
# Spectre                      NaN
# Casino Royale                3.3

# %%
df.nsmallest(5,'Box Office')
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
# Casino Royale                    1967     David Niven     Ken Hughes
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2
# Casino Royale                         315.0    85.0                NaN

# %%
# can also be called directly on a series
df["Budget"].nlargest(4)
# Out:
# Film
# Spectre                    206.3
# Quantum of Solace          181.4
# Skyfall                    170.2
# The World Is Not Enough    158.3
# Name: Budget, dtype: float64

# %%
df.nlargest()

# %%
df.nlargest( 5, ['Box Office','Budget'])
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Skyfall        2012  Daniel Craig       Sam Mendes       943.5   170.2
# Thunderball    1965  Sean Connery    Terence Young       848.1    41.9
# Goldfinger     1964  Sean Connery     Guy Hamilton       820.4    18.6
# Spectre        2015  Daniel Craig       Sam Mendes       726.7   206.3
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Skyfall                     14.5
# Thunderball                  4.7
# Goldfinger                   3.2
# Spectre                      NaN
# Casino Royale                3.3

# %% [markdown]
# # Filtering DF with where() method

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# Where return un DF avec des valeurs reelles pour les lignes qui s'accordent à la requete, 
# le reste sera replacé par des Nan
########################"
# commençons par un filtre simple
v_ = df['Actor'] == 'Sean Connery'
df[v_]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
# avec where 
df.where(v_)
# Out:
#                                    Year         Actor        Director  \
# Film
# Dr. No                           1962.0  Sean Connery   Terence Young
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Thunderball                      1965.0  Sean Connery   Terence Young
# Casino Royale                       NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Live and Let Die                    NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# ...

# %%
# nous pouvons specifier une valeur à al place de Nan
df.where(v_, other = 'forget')

# %% [markdown]
# # Filter a DF with the .query() method

# %%
# .query() method works with columns names that do not have spaces
# we first need to replace spaces with '_' par example

# %%
# the fastest way's
df.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box_Office', 'Budget',
#        'Bond_Actor_Salary'],
#       dtype='object')

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]
# or
# df.columns = ['Year','Actor', 'Director', 'Box_Office','Budget','Bond_Actor_Salary']

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# let's use .query() method
df.query('Actor == "Roger Moore"')
# Out:
#                              Year        Actor       Director  Box_Office  \
# Film
# Live and Let Die             1973  Roger Moore   Guy Hamilton       460.3
# The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977  Roger Moore  Lewis Gilbert       533.0
# Moonraker                    1979  Roger Moore  Lewis Gilbert       535.0
# For Your Eyes Only           1981  Roger Moore      John Glen       449.4
# Octopussy                    1983  Roger Moore      John Glen       373.8
# A View to a Kill             1985  Roger Moore      John Glen       275.2
#
#                              Budget  Bond_Actor_Salary
# Film
# Live and Let Die               30.8                NaN
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN
# Moonraker                      91.5                NaN
# For Your Eyes Only             60.2                NaN
# ...

# %%
# or
df.query('Actor != "Roger Moore"').head()
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
df.query('Actor == "Sean Connery" and Director == "Terence Young" ')
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
df.query('Actor in ["Sean Connery", "David Niven"]')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# Casino Royale          1967   David Niven      Ken Hughes       315.0    85.0
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN
# ...

# %% [markdown]
# # Quick review on .apply() method

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %% [markdown]
# ### .apply() on a single series

# %%
# ex
def convert_to_string_and_add_million(number):
    return str(number)+ 'MILLIONS!'

# %%
df['Box_Office'].apply(convert_to_string_and_add_million)
# Out:
# Film
# Dr. No                             448.8MILLIONS!
# From Russia with Love              543.8MILLIONS!
# Goldfinger                         820.4MILLIONS!
# Thunderball                        848.1MILLIONS!
# Casino Royale                      315.0MILLIONS!
# You Only Live Twice                514.2MILLIONS!
# On Her Majesty's Secret Service    291.5MILLIONS!
# Diamonds Are Forever               442.5MILLIONS!
# Live and Let Die                   460.3MILLIONS!
# The Man with the Golden Gun        334.0MILLIONS!
# The Spy Who Loved Me               533.0MILLIONS!
# Moonraker                          535.0MILLIONS!
# For Your Eyes Only                 449.4MILLIONS!
# Never Say Never Again              380.0MILLIONS!
# Octopussy                          373.8MILLIONS!
# A View to a Kill                   275.2MILLIONS!
# The Living Daylights               313.5MILLIONS!
# Licence to Kill                    250.9MILLIONS!
# GoldenEye                          518.5MILLIONS!
# ...

# %%
# identically , we can do it with the Budget column
df['Budget'].apply(convert_to_string_and_add_million)
# Out:
# Film
# Dr. No                               7.0MILLIONS!
# From Russia with Love               12.6MILLIONS!
# Goldfinger                          18.6MILLIONS!
# Thunderball                         41.9MILLIONS!
# Casino Royale                       85.0MILLIONS!
# You Only Live Twice                 59.9MILLIONS!
# On Her Majesty's Secret Service     37.3MILLIONS!
# Diamonds Are Forever                34.7MILLIONS!
# Live and Let Die                    30.8MILLIONS!
# The Man with the Golden Gun         27.7MILLIONS!
# The Spy Who Loved Me                45.1MILLIONS!
# Moonraker                           91.5MILLIONS!
# For Your Eyes Only                  60.2MILLIONS!
# Never Say Never Again               86.0MILLIONS!
# Octopussy                           53.9MILLIONS!
# A View to a Kill                    54.5MILLIONS!
# The Living Daylights                68.8MILLIONS!
# Licence to Kill                     56.7MILLIONS!
# GoldenEye                           76.9MILLIONS!
# ...

# %%
# now, let's use this function more nicely
# instead of doing this operation column by column, we can use a simple loop as:
columns = ['Box_Office', 'Budget','Bond_Actor_Salary' ]
for tmp in columns:
    df[tmp] = df[tmp].apply(convert_to_string_and_add_million)

# %%
df.head(30)
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ### The .apply() method with rows values

# %%
df = pd.read_csv('./pandas/jamesbond.csv', index_col = 'Film')
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# cette fois ci nous utilisons apply() sur les rows du DF
# ex : si nous voulons attribuer automatiquement un review sur chacun des films, en function du nom de l'acteur 
# et le budget de realisation
def movie_review(row):
    actor, budget = row[1], row[4]
    if actor  == "Sean Connery":
        return 'excellent'
    elif actor == 'Roger Moore' and budget >= 40:
        return 'moyen'
    else:
        return 'aucune idea'

# %%
df.apply(movie_review, axis = 1) # or axis = 'columns'

# %%
# we can store this data in new col
df['review'] = df.apply(movie_review, axis = 1)

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary       review
# Film
# Dr. No                               0.6    excellent
# From Russia with Love                1.6    excellent
# Goldfinger                           3.2    excellent
# Thunderball                          4.7    excellent
# Casino Royale                        NaN  aucune idea

# %% [markdown]
# # Create a DF copy with .copy() Method
# * cree une copie du DF et le sauvegarde en memo

# %%
df = pd.read_csv('./pandas/jamesbond.csv', index_col = 'Film')
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
# verifions une premiere operation
df['Director']
# Out:
# Film
# Dr. No                                  Terence Young
# From Russia with Love                   Terence Young
# Goldfinger                               Guy Hamilton
# Thunderball                             Terence Young
# Casino Royale                              Ken Hughes
# You Only Live Twice                     Lewis Gilbert
# On Her Majesty's Secret Service         Peter R. Hunt
# Diamonds Are Forever                     Guy Hamilton
# Live and Let Die                         Guy Hamilton
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# Moonraker                               Lewis Gilbert
# For Your Eyes Only                          John Glen
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# A View to a Kill                            John Glen
# The Living Daylights                        John Glen
# ...

# %%
# sauvegardons le dans une variable
direct = df['Director']
direct.head()
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Thunderball              Terence Young
# Casino Royale               Ken Hughes
# Name: Director, dtype: object

# %%
# essayons de modifier le nom d'un directeur
direct['From Russia with Love'] = 'Mr Terence Young'
# Out:
# /home/rodrique/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# le problm est que nous essayons de remplacer une valeur du df d'origine, et nous avons donc cet avertissement
# nous pouvons verifier que le director di=u film en question a ete effectivement modifié dans la base de donnée 
df.head()
# Out:
#                        Year         Actor          Director  Box Office  \
# Film
# Dr. No                 1962  Sean Connery     Terence Young       448.8
# From Russia with Love  1963  Sean Connery  Mr Terence Young       543.8
# Goldfinger             1964  Sean Connery      Guy Hamilton       820.4
# Thunderball            1965  Sean Connery     Terence Young       848.1
# Casino Royale          1967   David Niven        Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Thunderball              41.9                4.7
# Casino Royale            85.0                NaN

# %%
# alors pour eviter cela, nous devos creer une copy() de la valeur en cours que nous souhaitons modifier
#
df = pd.read_csv('./pandas/jamesbond.csv', index_col = 'Film')
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
direct = df['Director'].copy()
direct.head()
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Thunderball              Terence Young
# Casino Royale               Ken Hughes
# Name: Director, dtype: object

# %%
# nous pouvons maintenant modifier cette valeur tranquillement
direct['From Russia with Love'] = 'Mr Terence Young'

# %%
direct.head()
# Out:
# Film
# Dr. No                      Terence Young
# From Russia with Love    Mr Terence Young
# Goldfinger                   Guy Hamilton
# Thunderball                 Terence Young
# Casino Royale                  Ken Hughes
# Name: Director, dtype: object

# %%
# la valeur dans le DF initial ne change pas
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %% [markdown]
# # Bonus
# * https://www.datasciencecentral.com/profiles/blogs/python-pandas-an-in-depth-tool-for-data-analytics#ToobaAhmedAlvi44319
