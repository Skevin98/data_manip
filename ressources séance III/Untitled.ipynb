# %%
import pandas as pd

# %%
df = pd.read_csv('./data/employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df = pd.read_csv('./data/employees.csv', parse_dates = ['Start Date','Last Login Time'])

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df = pd.read_csv('./data/employees.csv', parse_dates = ['Start Date','Last Login Time'])

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-08-02 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-08-02 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-08-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df[df['Team'] == 'Finance']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-08-02 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-08-02 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2021-08-02 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2021-08-02 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2021-08-02 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2021-08-02 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2021-08-02 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2021-08-02 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
mask = df['Team'] == 'Finance'

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-08-02 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-08-02 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2021-08-02 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2021-08-02 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2021-08-02 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2021-08-02 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2021-08-02 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2021-08-02 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
df[df['Senior Management']==True]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2021-08-02 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2021-08-02 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2021-08-02 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-08-02 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2021-08-02 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
mask = df['Team'] != 'Finance'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-08-02 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2021-08-02 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-08-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-08-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df['Salary'] > 100000
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Salary, Length: 1000, dtype: bool

# %%
df['Start Date'] > '2002-08-25'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: Start Date, Length: 1000, dtype: bool

# %%
df = pd.read_csv('./data/employees.csv', parse_dates = ['Start Date','Last Login Time'])

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head(2)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN

# %%
tmp1 = df['Gender'] == 'Male'
tmp2 = df['Team'] == 'Marketing'
tmp3 = df['Senior Management']
df[tmp1 & tmp2 & tmp3].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 26       Craig   Male 2000-02-27 2021-08-02 07:45:00   37598    7.757
# 77     Charles   Male 2004-09-14 2021-08-02 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 204     Willie   Male 2006-06-06 2021-08-02 09:45:00   55281    4.935
#
#      Senior Management       Team
# 0                 True  Marketing
# 26                True  Marketing
# 77                True  Marketing
# 101               True  Marketing
# 204               True  Marketing

# %%
tmp1 = df['Team'] == 'Legal'
tmp2 = df['Team'] == 'Marketing'
tmp3 = df['Team'] == 'Product'
df[tmp1 | tmp2 | tmp3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-08-02 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-08-02 15:19:00  102508   12.637
# 15     Lillian  Female 2016-06-05 2021-08-02 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 986      Donna  Female 1982-11-26 2021-08-02 07:04:00   82871   17.999
# 989     Justin     NaN 1991-02-10 2021-08-02 16:58:00   38344    3.794
# 991       Rose  Female 2002-08-25 2021-08-02 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
#
#      Senior Management       Team
# 0                 True  Marketing
# 5                False      Legal
# ...

# %%
filter_val = df['Team'].isin(['Legal','Marketing','Product'])

# %%
df[filter_val]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-08-02 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-08-02 15:19:00  102508   12.637
# 15     Lillian  Female 2016-06-05 2021-08-02 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 986      Donna  Female 1982-11-26 2021-08-02 07:04:00   82871   17.999
# 989     Justin     NaN 1991-02-10 2021-08-02 16:58:00   38344    3.794
# 991       Rose  Female 2002-08-25 2021-08-02 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
#
#      Senior Management       Team
# 0                 True  Marketing
# 5                False      Legal
# ...

# %%
df[df.isin(['Male', 'Legal'])]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0          NaN   Male        NaT             NaT     NaN      NaN
# 1          NaN   Male        NaT             NaT     NaN      NaN
# 2          NaN    NaN        NaT             NaT     NaN      NaN
# 3          NaN   Male        NaT             NaT     NaN      NaN
# 4          NaN   Male        NaT             NaT     NaN      NaN
# ..         ...    ...        ...             ...     ...      ...
# 995        NaN    NaN        NaT             NaT     NaN      NaN
# 996        NaN   Male        NaT             NaT     NaN      NaN
# 997        NaN   Male        NaT             NaT     NaN      NaN
# 998        NaN   Male        NaT             NaT     NaN      NaN
# 999        NaN   Male        NaT             NaT     NaN      NaN
#
#      Senior Management Team
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                  NaN  NaN
# 3                  NaN  NaN
# ...

# %%
df[df['Team'].isnull()]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2021-08-02 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2021-08-02 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2021-08-02 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2021-08-02 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2021-08-02 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2021-08-02 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2021-08-02 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2021-08-02 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2021-08-02 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2021-08-02 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2021-08-02 06:06:00   66067   10.957
# ...

# %%
df[df['Team'].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2021-08-02 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-08-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-08-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-08-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
border = df[df['Salary'].between(145146,146908)]

# %%
border
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 44      Cynthia  Female 1988-11-16 2021-08-02 18:54:00  145146    7.482
# 132      Carlos    Male 1995-01-04 2021-08-02 07:02:00  146670   10.763
# 142   Elizabeth  Female 2003-10-09 2021-08-02 17:53:00  146129    5.687
# 175      Willie    Male 1998-02-17 2021-08-02 20:20:00  146651    1.451
# 269         NaN  Female 1992-08-02 2021-08-02 20:35:00  145316   18.517
# 319  Jacqueline  Female 1981-11-25 2021-08-02 15:01:00  145988   18.243
# 452       Scott    Male 2012-11-17 2021-08-02 14:47:00  146812    1.965
# 536    Clarence    Male 1982-08-26 2021-08-02 09:47:00  146589    4.905
# 665     Anthony    Male 2013-02-13 2021-08-02 13:35:00  146141    3.645
# 720       Marie  Female 1983-04-08 2021-08-02 14:01:00  145988   18.685
# 750       Louis     NaN 1983-02-05 2021-08-02 18:39:00  145274   16.379
# 808       Julie  Female 1980-03-08 2021-08-02 05:13:00  145357    3.459
# ...

# %%
df['Last Login Time'].between('06:00AM', '06:00PM')
df[df['Last Login Time'].between('06:00AM', '06:00PM')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-08-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-08-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2021-08-02 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2021-08-02 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-08-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-08-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-08-02 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df = pd.read_csv('./data/employees.csv', parse_dates = ['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.sort_values('First Name',inplace = True)
df.head(2)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
#
#      Senior Management       Team
# 101               True  Marketing
# 327               True  Marketing

# %%
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
x = ~df['First Name'].duplicated(keep = False)

# %%
x
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
#        ...
# 902    False
# 925    False
# 946    False
# 947    False
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[x].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-08-02 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-08-02 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-08-02 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-08-02 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance
# 887              False        Legal
# 5                False        Legal

# %%
x = df['First Name'].duplicated()

# %%
x
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[x].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-08-02 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2021-08-02 19:39:00   63126   18.424
# 141       Adam   Male 1990-12-24 2021-08-02 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2021-08-02 11:59:00   71276    5.027
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources

# %%
df.head(2)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
#
#      Senior Management       Team
# 101               True  Marketing
# 327               True  Marketing

# %%
df[x].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-08-02 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2021-08-02 19:39:00   63126   18.424
# 141       Adam   Male 1990-12-24 2021-08-02 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2021-08-02 11:59:00   71276    5.027
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources

# %%
x = df['First Name'].duplicated(keep = 'last')

# %%
x
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[x].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-08-02 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2021-08-02 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2021-08-02 20:57:00  110194   14.727
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product

# %%
x = ~df['First Name'].duplicated(keep = 'last')

# %%
df[x].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2021-08-02 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2021-08-02 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2021-08-02 00:26:00   41453   10.084
# 959     Albert    Male 1992-09-19 2021-08-02 02:35:00   45094    5.850
# 693      Alice  Female 1995-10-16 2021-08-02 21:19:00   92799    2.782
#
#      Senior Management                  Team
# 937              False       Client Services
# 538              False       Human Resources
# 610              False               Product
# 959               True  Business Development
# 693              False                 Sales

# %%
x = ~df['First Name'].duplicated(keep = 'first')

# %%
df[x].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2021-08-02 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2021-08-02 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2021-08-02 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2021-08-02 09:34:00   47638   11.209
#
#      Senior Management             Team
# 101               True        Marketing
# 137              False     Distribution
# 300               True      Engineering
# 372               True      Engineering
# 988              False  Human Resources

# %%
x = ~df['First Name'].duplicated(keep = 'last')

# %%
df[x].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2021-08-02 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2021-08-02 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2021-08-02 00:26:00   41453   10.084
# 959     Albert    Male 1992-09-19 2021-08-02 02:35:00   45094    5.850
# 693      Alice  Female 1995-10-16 2021-08-02 21:19:00   92799    2.782
#
#      Senior Management                  Team
# 937              False       Client Services
# 538              False       Human Resources
# 610              False               Product
# 959               True  Business Development
# 693              False                 Sales

# %%
x = ~df['First Name'].duplicated(keep = False)

# %%
df[x].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-08-02 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-08-02 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-08-02 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-08-02 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-08-02 01:35:00  115163   10.125
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance
# 887              False        Legal
# 5                False        Legal

# %%
x = df['First Name'].duplicated(keep = False)

# %%
df[x].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-08-02 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2021-08-02 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2021-08-02 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ['First Name'], keep = 'first')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2021-08-02 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2021-08-02 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2021-08-02 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2021-08-02 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2021-08-02 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2021-08-02 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2021-08-02 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2021-08-02 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2021-08-02 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df = pd.read_csv('./data/employees.csv', parse_dates = ['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.sort_values('First Name',inplace = True)
df.head(2)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-02 18:48:00   58755    5.097
#
#      Senior Management       Team
# 101               True  Marketing
# 327               True  Marketing

# %%
df['Gender']
# Out:
# 101      Male
# 327      Male
# 440      Male
# 937       NaN
# 137      Male
#         ...
# 902      Male
# 925    Female
# 946    Female
# 947      Male
# 951    Female
# Name: Gender, Length: 1000, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df['Gender'].unique()
# Out:
# ['Male', NaN, 'Female']
# Categories (2, object): ['Male', 'Female']

# %%
df['Team'].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
df['Team'].nunique()
# Out:
# 10

# %%
df['Team'].nunique(dropna=False)
# Out:
# 11

# %%
df = pd.DataFrame([['Math', 'en ligne', 2, False],['Data Processing','presentiel', 9, True],['Python', 'en ligne', 6, True],['SGBDR', 'en ligne', 5, False],['BD Spatiale', 'presentiel',4, False],['Rech Biblio', 'mixte', 8, True],['IA', 'presentiel', 4, True]])

# %%
df
# Out:
#                  0           1  2      3
# 0             Math    en ligne  2  False
# 1  Data Processing  presentiel  9   True
# 2           Python    en ligne  6   True
# 3            SGBDR    en ligne  5  False
# 4      BD Spatiale  presentiel  4  False
# 5      Rech Biblio       mixte  8   True
# 6               IA  presentiel  4   True

# %%
df.rename(mapper = {0:'Module',
1:'Modal_Cours',2:'Coeff',3:'Valider'}, axis =1)
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 5      Rech Biblio       mixte      8     True
# 6               IA  presentiel      4     True

# %%
df
# Out:
#                  0           1  2      3
# 0             Math    en ligne  2  False
# 1  Data Processing  presentiel  9   True
# 2           Python    en ligne  6   True
# 3            SGBDR    en ligne  5  False
# 4      BD Spatiale  presentiel  4  False
# 5      Rech Biblio       mixte  8   True
# 6               IA  presentiel  4   True

# %%
df.rename(mapper = {0:'Module',
1:'Modal_Cours',2:'Coeff',3:'Valider'}, axis =1, inplace = True)

# %%
df
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 5      Rech Biblio       mixte      8     True
# 6               IA  presentiel      4     True

# %%
tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Coeff'] > 7
tmp3 = df['Valider'] == True

# %%
df[tmp1 & tmp2 & tmp3]
# Out:
# Empty DataFrame
# Columns: [Module, Modal_Cours, Coeff, Valider]
# Index: []

# %%
tmp2 = df['Coeff'] > 5

# %%
df[tmp1 & tmp2 & tmp3]
# Out:
#    Module Modal_Cours  Coeff  Valider
# 2  Python    en ligne      6     True

# %%
tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Coeff'] > 7
tmp3 = df['Valider'] == True
df[tmp1 & tmp2 & tmp3]
# Out:
# Empty DataFrame
# Columns: [Module, Modal_Cours, Coeff, Valider]
# Index: []

# %%
tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Coeff'] > 8
df[tmp1 | tmp2]
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False

# %%
df
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 5      Rech Biblio       mixte      8     True
# 6               IA  presentiel      4     True

# %%
#les cours en ligne non validés ou les cours en presentiel validés

tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Valider'] == False
tmp3 = df['Modal_Cours'].isin(['presentiel'])
tmp4 = df['Valider']
df[tmp1 & tmp2 | tmp3 & tmp4]
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 3            SGBDR    en ligne      5    False
# 6               IA  presentiel      4     True

# %%
tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Valider'] == False
tmp3 = df['Modal_Cours'].isin(['presentiel'])
tmp4 = df['Valider']
df[tmp1 & tmp2 | tmp3 & tmp4]
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 3            SGBDR    en ligne      5    False
# 6               IA  presentiel      4     True

# %%
#les cours en ligne non validés ou les cours en presentiel validés

tmp1 = df['Modal_Cours'].isin(['en ligne'])
tmp2 = df['Valider'] == False
tmp3 = df['Modal_Cours'].isin(['presentiel'])
tmp4 = df['Valider']
df[tmp1 & tmp2 | tmp3 & tmp4]
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 3            SGBDR    en ligne      5    False
# 6               IA  presentiel      4     True
